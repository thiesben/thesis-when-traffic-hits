# %% [markdown]
# # Get a Trip Sample

# %%
import geopandas as gpd
import multiprocessing as mp
import numpy as np
import os
import osmnx as ox
import pandas as pd
from statsmodels.discrete.count_model import ZeroInflatedPoisson
from statsmodels.tools.tools import add_constant

from scipy._lib._util import _lazywhere
import statsmodels.distributions.discrete
statsmodels.distributions.discrete._lazywhere = _lazywhere

from config import rpath
os.chdir(rpath)

# %%
path = "data/Berlin_2017/data/trips"
files = os.listdir(path)
colnames = ["TripID","DeviceID","ProviderID","Mode","StartDate","StartWday","EndDate","EndWDay","StartLocLat",
            "StartLocLon", "EndLocLat","EndLocLon","IsStartHome","IsEndHome", "GeospatialType","ProviderType",
            "ProviderDrivingProfile","VehicleWeightClass","ProbeSourceType","OriginZoneName","DestinationZoneName",
            "MultipleZones","MultipleCorridors","EndpointType","TripMeanSpeedKph","TripMaxSpeedKph","TripDistanceMeters",
            "MovementType","OriginCensusBlockGroup","DestinationCensucBlockGroup"]
keepcols = ["TripID","DeviceID","StartDate","EndDate","StartLocLat","StartLocLon", "EndLocLat","EndLocLon", "ProviderType",
            "ProviderDrivingProfile","VehicleWeightClass","TripMeanSpeedKph","TripMaxSpeedKph","TripDistanceMeters",
            "MovementType"]

# %%
for i, file in enumerate(files):
    if i== 0:
        df = pd.read_csv(os.path.join(path,file), names = colnames)
        df = df[keepcols]
    else:
        df = df.append(pd.read_csv(os.path.join(path,file), names=colnames)[keepcols])
    print("Read file", i+1, "of", len(files))
# Out:
# Read file 1 of 14
# Read file 2 of 14
# Read file 3 of 14
# Read file 4 of 14
# Read file 5 of 14
# Read file 6 of 14
# Read file 7 of 14
# Read file 8 of 14
# Read file 9 of 14
# Read file 10 of 14
# Read file 11 of 14
# Read file 12 of 14
# Read file 13 of 14
# Read file 14 of 14

# %%
N = len(set(df.TripID.tolist()))
n_sample = int(np.round(N*0.8729,0))
print("Drawing a sample of size", n_sample, "out of", N, "total trips.")
trip_sample = df["TripID"].sample(n=n_sample, random_state=1337).tolist()
np.save("tripsample_5-3.npy", np.array(trip_sample))
# Out:
# Drawing a sample of size 29861135 out of 34209113 total trips.

# %% [markdown]
# ## Calculate new Rv
# Everything taken from the original RV notebook

# %%
# Get Waypoint Files
path = "data/Berlin_2017/data/waypoints"
files = []
for file in os.listdir(path):
    if file.endswith("edges.csv"):
        files.append(os.path.join(path,file))
files.sort()
keepcols = ['TripID', 'WaypointSequence', 'CaptureDate','RawSpeed', 'edge_1', 'edge_2', 'edge_dist']

tripsample = np.load("tripsample_5-3.npy")

# %%
def read_filter_index(file):
    '''This function reads a waypoint file, gets the CET timestamp and filters the data frame 
       to only include files from the peak hours and those which could be sensibly matched with 
       a road from the street network. It then adds an "edge_id" and a "time_id" to the data frame,
       which are unique edge identifiers and 15-minute time interval identifiers within the
       defined time windows, respectively.
    '''
    # Read file
    gdf = pd.read_csv(file)[keepcols] # note to self: dtypes are being read correctly
    len_gdf = len(gdf)
    gdf = gdf[gdf.TripID.isin(tripsample)] # keep only those which are in tripsample
    print(len(gdf)-len_gdf, "waypoints discarded.")
    
    # Convert CaptureDate to TimeStamp and convert to CET
    gdf["Timestamp_CET"] = pd.to_datetime(gdf["CaptureDate"], format='%Y-%m-%dT%H:%M:%S') 
    gdf["Timestamp_CET"] = pd.DatetimeIndex(gdf.Timestamp_CET).tz_convert('Europe/Berlin').to_series().tolist() 
    gdf = gdf.drop(columns="CaptureDate")
    
    # Get the edge distances to eventually create a histogram or a quantile overview
    edge_dist_list = gdf.edge_dist
    
    # Filter dataframe to only include peak hours during weekdays
    gdf = gdf[gdf.Timestamp_CET.dt.weekday < 5] # 5 = Saturday, 6 = Sunday
    gdf = gdf[((gdf.Timestamp_CET.dt.hour >= 6) & (gdf.Timestamp_CET.dt.hour < 10)) |
              ((gdf.Timestamp_CET.dt.hour >= 14) & (gdf.Timestamp_CET.dt.hour < 20))]
    
    
    # Drop observations that couldn't be matched to a street segment very well
    gdf = gdf[gdf["edge_dist"]<=50] 
    gdf = gdf.drop(columns="edge_dist")
    
    # Create new unique edge ID column
    gdf["edge_id"] = gdf[["edge_1","edge_2"]].astype(str).agg('-'.join, axis=1)
    
    # Add time identifier
    # Create time index for 15 minute blocks
    conditions = [
        ((gdf.Timestamp_CET.dt.hour == 6) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 6) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 6) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 6) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 7) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 7) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 7) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 7) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 8) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 8) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 8) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 8) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 9) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 9) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 9) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 9) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 14) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 14) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 14) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 14) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 15) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 15) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 15) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 15) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 16) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 16) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 16) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 16) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 17) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 17) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 17) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 17) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 18) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 18) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 18) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 18) & (gdf.Timestamp_CET.dt.minute >= 45)),
        ((gdf.Timestamp_CET.dt.hour == 19) & (gdf.Timestamp_CET.dt.minute < 15)),
        ((gdf.Timestamp_CET.dt.hour == 19) & (gdf.Timestamp_CET.dt.minute >= 15) & (gdf.Timestamp_CET.dt.minute < 30)),
        ((gdf.Timestamp_CET.dt.hour == 19) & (gdf.Timestamp_CET.dt.minute >= 30) & (gdf.Timestamp_CET.dt.minute < 45)),
        ((gdf.Timestamp_CET.dt.hour == 19) & (gdf.Timestamp_CET.dt.minute >= 45)),
    ]
    values = list(range(len(conditions))) # Corresponding condition values
    gdf['time_id'] = np.select(conditions, values) 
    
    return (gdf, edge_dist_list)

def get_Rv(file, verbose=True, use_files=True):
    '''Reads a file, applies filtering (see read_filter_index), saves the file, and
       computes Rv data frame for each segment and time id. Additionally returns a 
       list of edge_distances.
    '''
    pathfiles = [path + "/" + f for f in os.listdir(path)]
    
    if use_files:
        if file[:-4] + "_small_2020-sample.csv" in pathfiles:
            print("Reading old file...")
            gdf = pd.read_csv(file[:-4] + "_small_2020-sample.csv")
            edge_dist_list = []
        else:
            print("Reading new file...")
            gdf, edge_dist_list = read_filter_index(file)
    else:
        gdf, edge_dist_list = read_filter_index(file)
        
    if verbose:
        print("A file was processed")
    
    # Save
    if not file[:-4] + "_small_2020-sample.csv" in os.listdir(path):
        outfile = file[:-4] + "_small_2020-sample.csv"
        gdf.to_csv(outfile, index=False)
        
    # Drop unnecessary columns
    gdf = gdf.drop(columns=["edge_1", "edge_2"])
    
    # Return Rv df
    return gdf[['edge_id', 'time_id', 'RawSpeed']].groupby(['edge_id', 'time_id']).agg(['count', 'sum']), edge_dist_list

def get_and_process_Rv(files, verbose=True, cpus=6):
    ''' Gets Rv for every file, processes it to get a clean Rv table for every edge and quarter of an hour.
        Prints out quantiles of edge distances and returns clean Rv data frame.
    '''
    # Start the multiprocessing pool and get Rv
    pool = mp.Pool(processes=min(len(files), cpus))
    out = pool.map(get_Rv, files)
    pool.close()
    
    if verbose:
        print("Pool closed")

    Rv_list = [x[0] for x in out]
    edge_dist_list_list = [x[1] for x in out]
    
    del out # for space
    
    if verbose:
        print("Begin concatenating")
        
    Rv = pd.concat(Rv_list).groupby(['edge_id', 'time_id']).agg(['sum'])
    
    del Rv_list # for space
    
    # Remove entries that have n = 0 (only nan Speeds)
    Rv = Rv[Rv.xs(('RawSpeed','count', 'sum'), axis=1) != 0]
    
    # Remove obs with n < median n (20) on selected edge_id
    Rv = Rv[Rv.xs(('RawSpeed','count', 'sum'), axis=1) >= np.median(Rv.xs(("RawSpeed", "count", "sum"), axis=1))]
    print("The median count of observations on an edge is", np.median(Rv.xs(("RawSpeed", "count", "sum"), axis=1)))
    # Add meanSpeed column
    Rv.loc[:,"meanSpeed"] = Rv.xs(('RawSpeed','sum', 'sum'), axis=1)/Rv.xs(('RawSpeed','count', 'sum'), axis=1)
    
    if verbose:
        print("Begin merging lists")
        
    edge_dists = [item for sublist in edge_dist_list_list for item in sublist]
    edge_dists = np.array(edge_dists)
    print("# all waypoints: " + str(len(edge_dists)))
    print("# waypoints with dist >50: " + str(len(edge_dists[edge_dists<=50])))
    
    return Rv

# %%
Rv = get_and_process_Rv(files, cpus=5)
# Out:
# Reading old file...Reading old file...Reading old file...Reading new file...Reading old file...
#
#
#
#
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading old file...
# Reading old file...
# Reading old file...
# Reading new file...
# A file was processed
# A file was processed
# A file was processed
# Reading old file...
# Reading new file...
# Reading old file...
# A file was processed
# A file was processed
# -1054574 waypoints discarded.
# Reading new file...
# Reading old file...
# -1059038 waypoints discarded.
# A file was processed
# Reading new file...
# -1064497 waypoints discarded.
# -1083189 waypoints discarded.
# -1051615 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# Reading old file...
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# Reading old file...
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# Reading old file...
# Reading old file...
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1065085 waypoints discarded.
# -1061654 waypoints discarded.
# -1022484 waypoints discarded.
# -1063804 waypoints discarded.
# -1050326 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1091125 waypoints discarded.
# -1077551 waypoints discarded.
# -1053224 waypoints discarded.
# -1063007 waypoints discarded.
# -1050193 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1071780 waypoints discarded.
# -1037266 waypoints discarded.
# -1041626 waypoints discarded.
# -1075527 waypoints discarded.
# -1066980 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1064472 waypoints discarded.
# -1095880 waypoints discarded.
# -1098404 waypoints discarded.
# -1045610 waypoints discarded.
# -1057627 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1062643 waypoints discarded.
# -1099683 waypoints discarded.
# Reading new file...
# -1032050 waypoints discarded.
# -1043976 waypoints discarded.
# -1094675 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# A file was processed
# Reading new file...
# -1061108 waypoints discarded.
# -1069051 waypoints discarded.
# -1068602 waypoints discarded.
# Reading new file...
# -1082679 waypoints discarded.
# -1047166 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# A file was processed
# Reading new file...
# Reading new file...
# -1071693 waypoints discarded.
# -1050198 waypoints discarded.
# Reading new file...
# -1034081 waypoints discarded.
# -1072230 waypoints discarded.
# -1042001 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# A file was processed
# Reading new file...
# -1084586 waypoints discarded.
# Reading new file...
# -1082454 waypoints discarded.
# Reading new file...
# -1045588 waypoints discarded.
# -1078306 waypoints discarded.
# -1085315 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# A file was processed
# Reading new file...
# -1076441 waypoints discarded.
# -1080433 waypoints discarded.
# -1036089 waypoints discarded.
# -1042220 waypoints discarded.
# Reading new file...
# -1050414 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# A file was processed
# Reading new file...
# A file was processed
# -1076580 waypoints discarded.
# Reading new file...
# Reading new file...
# -1022512 waypoints discarded.
# Reading new file...
# -1071168 waypoints discarded.
# -1076264 waypoints discarded.
# -1080963 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# A file was processed
# Reading new file...
# Reading new file...
# -1085361 waypoints discarded.
# -1041818 waypoints discarded.
# -1051584 waypoints discarded.
# -1040320 waypoints discarded.
# Reading new file...
# -1057551 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# -1062299 waypoints discarded.
# Reading new file...
# Reading new file...
# A file was processed
# -1048266 waypoints discarded.
# -1081753 waypoints discarded.
# -1047274 waypoints discarded.
# Reading new file...
# -1081324 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# Reading new file...
# Reading new file...
# -1093669 waypoints discarded.
# A file was processed
# -1046182 waypoints discarded.
# -1040383 waypoints discarded.
# -1047154 waypoints discarded.
# A file was processed
# A file was processed
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# -1088939 waypoints discarded.
# Reading new file...
# -1056192 waypoints discarded.
# -1091846 waypoints discarded.
# A file was processed
# A file was processed
# Reading new file...
# A file was processed
# Reading new file...
# -1071728 waypoints discarded.
# -1092288 waypoints discarded.
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# -1032968 waypoints discarded.
# -1081005 waypoints discarded.
# A file was processed
# A file was processed
# Reading new file...
# Reading new file...
# -1069373 waypoints discarded.
# -1075566 waypoints discarded.
# A file was processed
# A file was processed
# Reading new file...
# -1057010 waypoints discarded.
# Reading new file...
# -1038540 waypoints discarded.
# A file was processed
# A file was processed
# Pool closed
# Begin concatenating
# The median count of observations on an edge is 71.0
# Begin merging lists
# # all waypoints: 584354187
# # waypoints with dist >50: 569073628

# %%
Rv.to_csv("data/Rv-2020-sample.csv")

# %% [markdown]
# # Calculate new RSI
# Everything taken from the original RSI notebook

# %%
Rv = pd.read_csv("data/Rv-2020-sample.csv", names = ['edge_id', 'time_id', 'n', 'speed', 'meanspeed'], skiprows=4)

# %%
# Create edge data frame to get speeds from the OSM graph
edges = pd.DataFrame({'edge_id':Rv.edge_id.unique()})
edges[["edge_1", "edge_2"]] = edges["edge_id"].str.split("-", expand=True)
edges["edge_1"] = edges["edge_1"].astype(int)
edges["edge_2"] = edges["edge_2"].astype(int)

# Get the graphs
G = ox.io.load_graphml("data/graphs/berlin-2851.graphml") # 
H = ox.simplification.simplify_graph(ox.io.load_graphml("data/graphs/Berlin-raw.graphml"))

# %%
nomaxspeeds = []
maxSpeeds = []

for i in range(len(edges)): # For every edge
    if (i+1) % 1000 == 0:
        print("Processing", i+1, "of", len(edges), "edges")
    
    # Check conditions that max speed is available in G
    maxspeedyes = 'maxspeed' in G[edges.iloc[i,1]][edges.iloc[i,2]][0]
    speed = None
    
    if maxspeedyes:
        speed = G[edges.iloc[i,1]][edges.iloc[i,2]][0]['maxspeed']
        if speed == "DE:urban":
            speed = 50

    # In case G does not have max speed info, look it up in newer graph
    if speed is None: # If there's no info in geoff's belin graph
        osmids = G[edges.iloc[i,1]][edges.iloc[i,2]][0]['osmid'] # get the individual OSM way IDs
        if type(osmids) == int: # If osmids is not a list but a single integer
            osmids = [osmids] # make it a list so we can loop through
        for oid in osmids: # for every way ID
            speed = None
            for u,v in H.edges(): # loop through all the edges in the unsimplified berlin graph
                if H[u][v][0]["osmid"] == oid: # if we find the way ID
                    if "maxspeed" in H[u][v][0]: # If we find maxspeed in graph
                        print("Found max speed in original graph")
                        speed = H[u][v][0]["maxspeed"]
                        break
                    elif "maxspeed:type" in H[u][v][0]: # If we find maxspeed type in graph
                        speed = H[u][v][0]["maxspeed:type"]
                        print("Found max speed type in original graph:", speed)
                        if speed == "DE:urban":
                            speed = 50
                            break
                        elif speed == "DE:zone30":
                            speed = 30
                            break
                        else:
                            print("ALARMALARM", speed)
                            raise Exception("TEST")
                            
    if speed is None: # If there's still no speed info
        print("Neither maxspeed nor maxspeed type info available for osmid", oid)
        nomaxspeeds.append(oid) 
        maxSpeeds.append(np.nan)
        continue        
            
    if type(speed) == list: # if there is more than one edge speed
        osmids = G[edges.iloc[i,1]][edges.iloc[i,2]][0]['osmid'] # get the individual OSM way IDs
        segmentlengths = []
        speeds = []
        if 'none' in speed: # if 'none' is in the speed list
                idx = speed.index('none') # find the index of the none entry
                speed.pop(idx) # pop the none entry
                speed = [float(x) for x in speed] # convert to float
        for oid in osmids: # for every way ID
            for u,v in H.edges(): # loop through all the edges in the unsimplified berlin graph
                try:
                    if H[u][v][0]["osmid"] == oid: # if we find the way ID
                        if "length" not in H[u][v][0] or "maxspeed" not in H[u][v][0]:
                            continue
                        else:
                            segmentlengths.append(H[u][v][0]["length"]) # get the segment length
                            speeds.append(H[u][v][0]["maxspeed"]) # and segment max speed
                except Exception as e:
                    print("An unknown exception incurred.")
                    print(i)
                    raise e
        if len(segmentlengths) == 0 or len(speeds) == 0: # if no way ID can be found
            speed = max(speed) # take the max speed of the existing speed list
        else:
            speed = (pd.DataFrame({'length':segmentlengths,'speed':speeds}) # Data frame with all segment lengths and speeds
                 .groupby("speed") # group by speeds
                 .agg("sum") # sum over segment lengths
                 .sort_values("length",ascending=False) # sort so that the longest segment is first
                 .index[0]) # get the index (speed) of the first entry (longest segment)
    maxSpeeds.append(speed)
# Out:
# Neither maxspeed nor maxspeed type info available for osmid 25368898
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 5116453
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 29112676
# Neither maxspeed nor maxspeed type info available for osmid 167410411
# Neither maxspeed nor maxspeed type info available for osmid 26406925
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 11405545
# Neither maxspeed nor maxspeed type info available for osmid 11405545
# Neither maxspeed nor maxspeed type info available for osmid 11405545
# Neither maxspeed nor maxspeed type info available for osmid 11405545
# Neither maxspeed nor maxspeed type info available for osmid 27156341
# Neither maxspeed nor maxspeed type info available for osmid 8792775
# Neither maxspeed nor maxspeed type info available for osmid 15920080
# Neither maxspeed nor maxspeed type info available for osmid 15920080
# Neither maxspeed nor maxspeed type info available for osmid 4515896
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 89583721
# Neither maxspeed nor maxspeed type info available for osmid 89583721
# Neither maxspeed nor maxspeed type info available for osmid 4808079
# Neither maxspeed nor maxspeed type info available for osmid 868550032
# Neither maxspeed nor maxspeed type info available for osmid 90094622
# Neither maxspeed nor maxspeed type info available for osmid 415858612
# Neither maxspeed nor maxspeed type info available for osmid 160130964
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 160130964
# Neither maxspeed nor maxspeed type info available for osmid 821773653
# Neither maxspeed nor maxspeed type info available for osmid 44202827
# Neither maxspeed nor maxspeed type info available for osmid 6229931
# Neither maxspeed nor maxspeed type info available for osmid 793150994
# Neither maxspeed nor maxspeed type info available for osmid 23453218
# Neither maxspeed nor maxspeed type info available for osmid 444570666
# Neither maxspeed nor maxspeed type info available for osmid 12305962
# Neither maxspeed nor maxspeed type info available for osmid 12305962
# Neither maxspeed nor maxspeed type info available for osmid 98723438
# Neither maxspeed nor maxspeed type info available for osmid 195386065
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 35859217
# Neither maxspeed nor maxspeed type info available for osmid 40193018
# Neither maxspeed nor maxspeed type info available for osmid 102777382
# Neither maxspeed nor maxspeed type info available for osmid 4804155
# Neither maxspeed nor maxspeed type info available for osmid 103051811
# Neither maxspeed nor maxspeed type info available for osmid 103108166
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 49707010
# Neither maxspeed nor maxspeed type info available for osmid 107377988
# Neither maxspeed nor maxspeed type info available for osmid 148631925
# Neither maxspeed nor maxspeed type info available for osmid 110464379
# Neither maxspeed nor maxspeed type info available for osmid 148885047
# Neither maxspeed nor maxspeed type info available for osmid 4776200
# Neither maxspeed nor maxspeed type info available for osmid 310017303
# Neither maxspeed nor maxspeed type info available for osmid 176195706
# Neither maxspeed nor maxspeed type info available for osmid 40193018
# Neither maxspeed nor maxspeed type info available for osmid 112581170
# Neither maxspeed nor maxspeed type info available for osmid 4776767
# Neither maxspeed nor maxspeed type info available for osmid 4776767
# Neither maxspeed nor maxspeed type info available for osmid 48907691
# Neither maxspeed nor maxspeed type info available for osmid 106653103
# Neither maxspeed nor maxspeed type info available for osmid 117879323
# Neither maxspeed nor maxspeed type info available for osmid 117879323
# Neither maxspeed nor maxspeed type info available for osmid 853231958
# Neither maxspeed nor maxspeed type info available for osmid 4474915
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 14118608
# Neither maxspeed nor maxspeed type info available for osmid 23756258
# Neither maxspeed nor maxspeed type info available for osmid 14118608
# Neither maxspeed nor maxspeed type info available for osmid 23756258
# Neither maxspeed nor maxspeed type info available for osmid 23756258
# Neither maxspeed nor maxspeed type info available for osmid 33847123
# Neither maxspeed nor maxspeed type info available for osmid 15742348
# Neither maxspeed nor maxspeed type info available for osmid 23756258
# Neither maxspeed nor maxspeed type info available for osmid 33847123
# Neither maxspeed nor maxspeed type info available for osmid 24422921
# Neither maxspeed nor maxspeed type info available for osmid 14120168
# Neither maxspeed nor maxspeed type info available for osmid 14134399
# Neither maxspeed nor maxspeed type info available for osmid 23121685
# Neither maxspeed nor maxspeed type info available for osmid 43711310
# Processing 1000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 121134232
# Neither maxspeed nor maxspeed type info available for osmid 121134232
# Neither maxspeed nor maxspeed type info available for osmid 121483964
# Neither maxspeed nor maxspeed type info available for osmid 27166148
# Neither maxspeed nor maxspeed type info available for osmid 383461023
# Neither maxspeed nor maxspeed type info available for osmid 696354580
# Neither maxspeed nor maxspeed type info available for osmid 696354579
# Neither maxspeed nor maxspeed type info available for osmid 123943336
# Neither maxspeed nor maxspeed type info available for osmid 124034876
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 30076968
# Neither maxspeed nor maxspeed type info available for osmid 846732249
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 30081258
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 31099803
# Neither maxspeed nor maxspeed type info available for osmid 31099803
# Neither maxspeed nor maxspeed type info available for osmid 191454755
# Neither maxspeed nor maxspeed type info available for osmid 854460710
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 846724605
# Neither maxspeed nor maxspeed type info available for osmid 31099801
# Neither maxspeed nor maxspeed type info available for osmid 191454755
# Neither maxspeed nor maxspeed type info available for osmid 31099800
# Neither maxspeed nor maxspeed type info available for osmid 35572430
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 38717012
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 14369551
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 126289880
# Neither maxspeed nor maxspeed type info available for osmid 193155133
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 52513361
# Neither maxspeed nor maxspeed type info available for osmid 338687111
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 41399045
# Neither maxspeed nor maxspeed type info available for osmid 142106565
# Neither maxspeed nor maxspeed type info available for osmid 551263764
# Neither maxspeed nor maxspeed type info available for osmid 137941886
# Neither maxspeed nor maxspeed type info available for osmid 128459777
# Neither maxspeed nor maxspeed type info available for osmid 28581614
# Neither maxspeed nor maxspeed type info available for osmid 28262153
# Neither maxspeed nor maxspeed type info available for osmid 16109891
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 128978595
# Neither maxspeed nor maxspeed type info available for osmid 128978595
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 154946524
# Neither maxspeed nor maxspeed type info available for osmid 154946524
# Neither maxspeed nor maxspeed type info available for osmid 154946523
# Neither maxspeed nor maxspeed type info available for osmid 131577614
# Neither maxspeed nor maxspeed type info available for osmid 131577614
# Neither maxspeed nor maxspeed type info available for osmid 19064220
# Neither maxspeed nor maxspeed type info available for osmid 19064220
# Neither maxspeed nor maxspeed type info available for osmid 82121192
# Neither maxspeed nor maxspeed type info available for osmid 82121192
# Neither maxspeed nor maxspeed type info available for osmid 14674294
# Neither maxspeed nor maxspeed type info available for osmid 211562073
# Neither maxspeed nor maxspeed type info available for osmid 14674289
# Neither maxspeed nor maxspeed type info available for osmid 14674290
# Neither maxspeed nor maxspeed type info available for osmid 14674291
# Neither maxspeed nor maxspeed type info available for osmid 14674289
# Neither maxspeed nor maxspeed type info available for osmid 14674294
# Neither maxspeed nor maxspeed type info available for osmid 82121192
# Neither maxspeed nor maxspeed type info available for osmid 82121192
# Neither maxspeed nor maxspeed type info available for osmid 152466417
# Neither maxspeed nor maxspeed type info available for osmid 48477475
# Neither maxspeed nor maxspeed type info available for osmid 133540564
# Neither maxspeed nor maxspeed type info available for osmid 133540564
# Neither maxspeed nor maxspeed type info available for osmid 100405511
# Neither maxspeed nor maxspeed type info available for osmid 101290100
# Neither maxspeed nor maxspeed type info available for osmid 25494196
# Neither maxspeed nor maxspeed type info available for osmid 25155311
# Neither maxspeed nor maxspeed type info available for osmid 25494198
# Neither maxspeed nor maxspeed type info available for osmid 133988454
# Neither maxspeed nor maxspeed type info available for osmid 133988454
# Neither maxspeed nor maxspeed type info available for osmid 151742519
# Neither maxspeed nor maxspeed type info available for osmid 32215238
# Processing 2000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 409715010
# Neither maxspeed nor maxspeed type info available for osmid 135708851
# Neither maxspeed nor maxspeed type info available for osmid 135708851
# Neither maxspeed nor maxspeed type info available for osmid 41350279
# Neither maxspeed nor maxspeed type info available for osmid 11027581
# Neither maxspeed nor maxspeed type info available for osmid 217003516
# Neither maxspeed nor maxspeed type info available for osmid 137688164
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 208580239
# Neither maxspeed nor maxspeed type info available for osmid 23905045
# Neither maxspeed nor maxspeed type info available for osmid 38095508
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 15244986
# Neither maxspeed nor maxspeed type info available for osmid 23597085
# Neither maxspeed nor maxspeed type info available for osmid 137728457
# Neither maxspeed nor maxspeed type info available for osmid 4776156
# Neither maxspeed nor maxspeed type info available for osmid 211517288
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 138624421
# Neither maxspeed nor maxspeed type info available for osmid 138624432
# Neither maxspeed nor maxspeed type info available for osmid 138624445
# Neither maxspeed nor maxspeed type info available for osmid 138624421
# Neither maxspeed nor maxspeed type info available for osmid 138624421
# Neither maxspeed nor maxspeed type info available for osmid 138624421
# Neither maxspeed nor maxspeed type info available for osmid 138624445
# Neither maxspeed nor maxspeed type info available for osmid 138624469
# Neither maxspeed nor maxspeed type info available for osmid 138624469
# Neither maxspeed nor maxspeed type info available for osmid 138624438
# Neither maxspeed nor maxspeed type info available for osmid 138624465
# Neither maxspeed nor maxspeed type info available for osmid 23792848
# Neither maxspeed nor maxspeed type info available for osmid 140353223
# Neither maxspeed nor maxspeed type info available for osmid 152354692
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 140649658
# Neither maxspeed nor maxspeed type info available for osmid 141124478
# Neither maxspeed nor maxspeed type info available for osmid 141145475
# Neither maxspeed nor maxspeed type info available for osmid 141145475
# Neither maxspeed nor maxspeed type info available for osmid 141804253
# Neither maxspeed nor maxspeed type info available for osmid 25747524
# Processing 3000 of 46828 edges
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 142575701
# Neither maxspeed nor maxspeed type info available for osmid 387478999
# Neither maxspeed nor maxspeed type info available for osmid 387478999
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 853248693
# Neither maxspeed nor maxspeed type info available for osmid 166973640
# Neither maxspeed nor maxspeed type info available for osmid 254493283
# Neither maxspeed nor maxspeed type info available for osmid 135708851
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 144533298
# Neither maxspeed nor maxspeed type info available for osmid 24325183
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 34178876
# Neither maxspeed nor maxspeed type info available for osmid 34178876
# Neither maxspeed nor maxspeed type info available for osmid 15808276
# Neither maxspeed nor maxspeed type info available for osmid 15808276
# Neither maxspeed nor maxspeed type info available for osmid 25491786
# Neither maxspeed nor maxspeed type info available for osmid 25491786
# Neither maxspeed nor maxspeed type info available for osmid 535695397
# Neither maxspeed nor maxspeed type info available for osmid 535695397
# Neither maxspeed nor maxspeed type info available for osmid 145795392
# Neither maxspeed nor maxspeed type info available for osmid 145795388
# Neither maxspeed nor maxspeed type info available for osmid 145795392
# Neither maxspeed nor maxspeed type info available for osmid 145934343
# Neither maxspeed nor maxspeed type info available for osmid 853248693
# Neither maxspeed nor maxspeed type info available for osmid 147476179
# Neither maxspeed nor maxspeed type info available for osmid 147476180
# Neither maxspeed nor maxspeed type info available for osmid 147476180
# Neither maxspeed nor maxspeed type info available for osmid 147476176
# Neither maxspeed nor maxspeed type info available for osmid 147717027
# Neither maxspeed nor maxspeed type info available for osmid 27266698
# Neither maxspeed nor maxspeed type info available for osmid 148117213
# Neither maxspeed nor maxspeed type info available for osmid 148288887
# Neither maxspeed nor maxspeed type info available for osmid 691112779
# Neither maxspeed nor maxspeed type info available for osmid 4927563
# Neither maxspeed nor maxspeed type info available for osmid 148303206
# Neither maxspeed nor maxspeed type info available for osmid 24160164
# Neither maxspeed nor maxspeed type info available for osmid 148329612
# Neither maxspeed nor maxspeed type info available for osmid 148329614
# Neither maxspeed nor maxspeed type info available for osmid 148614177
# Processing 4000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 25041940
# Neither maxspeed nor maxspeed type info available for osmid 207337333
# Neither maxspeed nor maxspeed type info available for osmid 149125751
# Neither maxspeed nor maxspeed type info available for osmid 16109891
# Neither maxspeed nor maxspeed type info available for osmid 149488400
# Neither maxspeed nor maxspeed type info available for osmid 149488401
# Neither maxspeed nor maxspeed type info available for osmid 149488399
# Neither maxspeed nor maxspeed type info available for osmid 149611534
# Neither maxspeed nor maxspeed type info available for osmid 149611534
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 150732372
# Neither maxspeed nor maxspeed type info available for osmid 4662762
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 40193019
# Neither maxspeed nor maxspeed type info available for osmid 151621386
# Neither maxspeed nor maxspeed type info available for osmid 151629371
# Neither maxspeed nor maxspeed type info available for osmid 152354619
# Neither maxspeed nor maxspeed type info available for osmid 151742461
# Neither maxspeed nor maxspeed type info available for osmid 151742429
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 16238530
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 695791478
# Found max speed in original graph
# Processing 5000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 152495022
# Neither maxspeed nor maxspeed type info available for osmid 152871033
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 602185580
# Neither maxspeed nor maxspeed type info available for osmid 211555483
# Neither maxspeed nor maxspeed type info available for osmid 211555483
# Neither maxspeed nor maxspeed type info available for osmid 153947884
# Neither maxspeed nor maxspeed type info available for osmid 30934754
# Neither maxspeed nor maxspeed type info available for osmid 30934754
# Neither maxspeed nor maxspeed type info available for osmid 846732249
# Neither maxspeed nor maxspeed type info available for osmid 31099800
# Neither maxspeed nor maxspeed type info available for osmid 23609110
# Neither maxspeed nor maxspeed type info available for osmid 36969679
# Neither maxspeed nor maxspeed type info available for osmid 16309056
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 36969679
# Neither maxspeed nor maxspeed type info available for osmid 154687897
# Neither maxspeed nor maxspeed type info available for osmid 154903682
# Neither maxspeed nor maxspeed type info available for osmid 79798710
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 239220369
# Neither maxspeed nor maxspeed type info available for osmid 155594969
# Neither maxspeed nor maxspeed type info available for osmid 714475175
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 23041845
# Neither maxspeed nor maxspeed type info available for osmid 23049267
# Neither maxspeed nor maxspeed type info available for osmid 28508710
# Neither maxspeed nor maxspeed type info available for osmid 156346066
# Neither maxspeed nor maxspeed type info available for osmid 156346044
# Neither maxspeed nor maxspeed type info available for osmid 156346044
# Neither maxspeed nor maxspeed type info available for osmid 156346044
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 156346044
# Neither maxspeed nor maxspeed type info available for osmid 156346044
# Neither maxspeed nor maxspeed type info available for osmid 37005673
# Neither maxspeed nor maxspeed type info available for osmid 23044858
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 126512818
# Neither maxspeed nor maxspeed type info available for osmid 156346068
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 156346060
# Neither maxspeed nor maxspeed type info available for osmid 156346111
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 156350676
# Neither maxspeed nor maxspeed type info available for osmid 128437137
# Neither maxspeed nor maxspeed type info available for osmid 4837326
# Processing 6000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 589687022
# Neither maxspeed nor maxspeed type info available for osmid 39349389
# Neither maxspeed nor maxspeed type info available for osmid 143949951
# Neither maxspeed nor maxspeed type info available for osmid 176037630
# Neither maxspeed nor maxspeed type info available for osmid 459221240
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 8008903
# Neither maxspeed nor maxspeed type info available for osmid 4493111
# Neither maxspeed nor maxspeed type info available for osmid 193373966
# Neither maxspeed nor maxspeed type info available for osmid 156817982
# Neither maxspeed nor maxspeed type info available for osmid 19433192
# Neither maxspeed nor maxspeed type info available for osmid 52608377
# Neither maxspeed nor maxspeed type info available for osmid 158580761
# Neither maxspeed nor maxspeed type info available for osmid 159081777
# Neither maxspeed nor maxspeed type info available for osmid 159081775
# Neither maxspeed nor maxspeed type info available for osmid 159081775
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 16769178
# Neither maxspeed nor maxspeed type info available for osmid 162363457
# Neither maxspeed nor maxspeed type info available for osmid 162363458
# Neither maxspeed nor maxspeed type info available for osmid 609032131
# Neither maxspeed nor maxspeed type info available for osmid 4978512
# Neither maxspeed nor maxspeed type info available for osmid 165729720
# Neither maxspeed nor maxspeed type info available for osmid 165729720
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 169208571
# Neither maxspeed nor maxspeed type info available for osmid 208345581
# Neither maxspeed nor maxspeed type info available for osmid 169558830
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 4068164
# Neither maxspeed nor maxspeed type info available for osmid 4068117
# Neither maxspeed nor maxspeed type info available for osmid 4068200
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4068176
# Neither maxspeed nor maxspeed type info available for osmid 4068117
# Neither maxspeed nor maxspeed type info available for osmid 4571081
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4463151
# Neither maxspeed nor maxspeed type info available for osmid 4068145
# Neither maxspeed nor maxspeed type info available for osmid 4068145
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 4571082
# Neither maxspeed nor maxspeed type info available for osmid 25571785
# Neither maxspeed nor maxspeed type info available for osmid 4571081
# Neither maxspeed nor maxspeed type info available for osmid 172098981
# Neither maxspeed nor maxspeed type info available for osmid 172098981
# Neither maxspeed nor maxspeed type info available for osmid 172183872
# Neither maxspeed nor maxspeed type info available for osmid 172183872
# Neither maxspeed nor maxspeed type info available for osmid 172183872
# Neither maxspeed nor maxspeed type info available for osmid 172183869
# Neither maxspeed nor maxspeed type info available for osmid 172183870
# Neither maxspeed nor maxspeed type info available for osmid 172183867
# Neither maxspeed nor maxspeed type info available for osmid 172183871
# Neither maxspeed nor maxspeed type info available for osmid 172183869
# Neither maxspeed nor maxspeed type info available for osmid 23809468
# Neither maxspeed nor maxspeed type info available for osmid 192487146
# Neither maxspeed nor maxspeed type info available for osmid 25939421
# Neither maxspeed nor maxspeed type info available for osmid 26807992
# Neither maxspeed nor maxspeed type info available for osmid 176037629
# Neither maxspeed nor maxspeed type info available for osmid 172699421
# Neither maxspeed nor maxspeed type info available for osmid 175298126
# Neither maxspeed nor maxspeed type info available for osmid 43963437
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 25605291
# Neither maxspeed nor maxspeed type info available for osmid 85637556
# Neither maxspeed nor maxspeed type info available for osmid 218724863
# Neither maxspeed nor maxspeed type info available for osmid 26807992
# Neither maxspeed nor maxspeed type info available for osmid 4829120
# Processing 7000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 175791108
# Neither maxspeed nor maxspeed type info available for osmid 176018756
# Neither maxspeed nor maxspeed type info available for osmid 176037628
# Neither maxspeed nor maxspeed type info available for osmid 44360530
# Neither maxspeed nor maxspeed type info available for osmid 176273221
# Neither maxspeed nor maxspeed type info available for osmid 176273224
# Neither maxspeed nor maxspeed type info available for osmid 176273223
# Neither maxspeed nor maxspeed type info available for osmid 153947334
# Neither maxspeed nor maxspeed type info available for osmid 24215165
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 647375435
# Neither maxspeed nor maxspeed type info available for osmid 180482046
# Neither maxspeed nor maxspeed type info available for osmid 180789857
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 175298126
# Neither maxspeed nor maxspeed type info available for osmid 175298126
# Neither maxspeed nor maxspeed type info available for osmid 251614883
# Neither maxspeed nor maxspeed type info available for osmid 183025307
# Neither maxspeed nor maxspeed type info available for osmid 251614884
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 18923807
# Neither maxspeed nor maxspeed type info available for osmid 18923807
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 200716209
# Neither maxspeed nor maxspeed type info available for osmid 759505898
# Neither maxspeed nor maxspeed type info available for osmid 186901892
# Neither maxspeed nor maxspeed type info available for osmid 186901892
# Neither maxspeed nor maxspeed type info available for osmid 23101888
# Neither maxspeed nor maxspeed type info available for osmid 23861004
# Neither maxspeed nor maxspeed type info available for osmid 188677946
# Neither maxspeed nor maxspeed type info available for osmid 6229931
# Neither maxspeed nor maxspeed type info available for osmid 190840603
# Neither maxspeed nor maxspeed type info available for osmid 368352441
# Neither maxspeed nor maxspeed type info available for osmid 26236456
# Neither maxspeed nor maxspeed type info available for osmid 19392260
# Neither maxspeed nor maxspeed type info available for osmid 19392260
# Neither maxspeed nor maxspeed type info available for osmid 111645301
# Neither maxspeed nor maxspeed type info available for osmid 191256029
# Neither maxspeed nor maxspeed type info available for osmid 4788443
# Neither maxspeed nor maxspeed type info available for osmid 4788443
# Neither maxspeed nor maxspeed type info available for osmid 25999940
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 194647623
# Neither maxspeed nor maxspeed type info available for osmid 437054291
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 651781877
# Neither maxspeed nor maxspeed type info available for osmid 419818727
# Neither maxspeed nor maxspeed type info available for osmid 419818727
# Neither maxspeed nor maxspeed type info available for osmid 195257600
# Neither maxspeed nor maxspeed type info available for osmid 28242485
# Neither maxspeed nor maxspeed type info available for osmid 206579085
# Neither maxspeed nor maxspeed type info available for osmid 708515798
# Neither maxspeed nor maxspeed type info available for osmid 162363458
# Neither maxspeed nor maxspeed type info available for osmid 19896498
# Neither maxspeed nor maxspeed type info available for osmid 4553268
# Processing 8000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 198830966
# Neither maxspeed nor maxspeed type info available for osmid 198942679
# Neither maxspeed nor maxspeed type info available for osmid 4606261
# Neither maxspeed nor maxspeed type info available for osmid 202154645
# Neither maxspeed nor maxspeed type info available for osmid 347658331
# Neither maxspeed nor maxspeed type info available for osmid 254552422
# Neither maxspeed nor maxspeed type info available for osmid 20135894
# Neither maxspeed nor maxspeed type info available for osmid 34106734
# Neither maxspeed nor maxspeed type info available for osmid 254552421
# Neither maxspeed nor maxspeed type info available for osmid 254552421
# Neither maxspeed nor maxspeed type info available for osmid 20135798
# Neither maxspeed nor maxspeed type info available for osmid 20135798
# Neither maxspeed nor maxspeed type info available for osmid 20135894
# Neither maxspeed nor maxspeed type info available for osmid 30829938
# Neither maxspeed nor maxspeed type info available for osmid 203211083
# Neither maxspeed nor maxspeed type info available for osmid 203211083
# Neither maxspeed nor maxspeed type info available for osmid 8149740
# Neither maxspeed nor maxspeed type info available for osmid 622614662
# Neither maxspeed nor maxspeed type info available for osmid 762502632
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 234463931
# Neither maxspeed nor maxspeed type info available for osmid 4687609
# Neither maxspeed nor maxspeed type info available for osmid 204947913
# Neither maxspeed nor maxspeed type info available for osmid 205079267
# Neither maxspeed nor maxspeed type info available for osmid 461840199
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 695791478
# Neither maxspeed nor maxspeed type info available for osmid 850224612
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 496931767
# Neither maxspeed nor maxspeed type info available for osmid 727049333
# Neither maxspeed nor maxspeed type info available for osmid 786323854
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 611506671
# Neither maxspeed nor maxspeed type info available for osmid 213528748
# Neither maxspeed nor maxspeed type info available for osmid 215367705
# Neither maxspeed nor maxspeed type info available for osmid 305137117
# Neither maxspeed nor maxspeed type info available for osmid 123943336
# Neither maxspeed nor maxspeed type info available for osmid 696354580
# Neither maxspeed nor maxspeed type info available for osmid 37005673
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 166974626
# Found max speed type in original graph: DE:urban
# Processing 9000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 156066238
# Neither maxspeed nor maxspeed type info available for osmid 708515798
# Neither maxspeed nor maxspeed type info available for osmid 149611534
# Neither maxspeed nor maxspeed type info available for osmid 228635045
# Neither maxspeed nor maxspeed type info available for osmid 228635045
# Neither maxspeed nor maxspeed type info available for osmid 228635046
# Neither maxspeed nor maxspeed type info available for osmid 148326359
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 229475732
# Neither maxspeed nor maxspeed type info available for osmid 135403248
# Neither maxspeed nor maxspeed type info available for osmid 229475750
# Neither maxspeed nor maxspeed type info available for osmid 229475761
# Neither maxspeed nor maxspeed type info available for osmid 229475741
# Neither maxspeed nor maxspeed type info available for osmid 148329614
# Neither maxspeed nor maxspeed type info available for osmid 229475752
# Neither maxspeed nor maxspeed type info available for osmid 229475757
# Neither maxspeed nor maxspeed type info available for osmid 229475738
# Neither maxspeed nor maxspeed type info available for osmid 759397216
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 166973638
# Neither maxspeed nor maxspeed type info available for osmid 4765927
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 22281062
# Found max speed in original graph
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 33284083
# Neither maxspeed nor maxspeed type info available for osmid 233763396
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 234540163
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 234868963
# Neither maxspeed nor maxspeed type info available for osmid 22875277
# Neither maxspeed nor maxspeed type info available for osmid 22701544
# Neither maxspeed nor maxspeed type info available for osmid 22730911
# Neither maxspeed nor maxspeed type info available for osmid 22730911
# Neither maxspeed nor maxspeed type info available for osmid 22730912
# Neither maxspeed nor maxspeed type info available for osmid 22730911
# Neither maxspeed nor maxspeed type info available for osmid 22730911
# Neither maxspeed nor maxspeed type info available for osmid 22730911
# Neither maxspeed nor maxspeed type info available for osmid 23044829
# Neither maxspeed nor maxspeed type info available for osmid 23044829
# Neither maxspeed nor maxspeed type info available for osmid 22779097
# Neither maxspeed nor maxspeed type info available for osmid 140106264
# Neither maxspeed nor maxspeed type info available for osmid 237026828
# Neither maxspeed nor maxspeed type info available for osmid 645343612
# Neither maxspeed nor maxspeed type info available for osmid 645343614
# Neither maxspeed nor maxspeed type info available for osmid 645343613
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 22875255
# Neither maxspeed nor maxspeed type info available for osmid 22875277
# Neither maxspeed nor maxspeed type info available for osmid 22875371
# Neither maxspeed nor maxspeed type info available for osmid 22875371
# Neither maxspeed nor maxspeed type info available for osmid 22875395
# Neither maxspeed nor maxspeed type info available for osmid 22875395
# Neither maxspeed nor maxspeed type info available for osmid 22875744
# Neither maxspeed nor maxspeed type info available for osmid 22875744
# Neither maxspeed nor maxspeed type info available for osmid 25198847
# Neither maxspeed nor maxspeed type info available for osmid 27106949
# Neither maxspeed nor maxspeed type info available for osmid 207412830
# Neither maxspeed nor maxspeed type info available for osmid 464171230
# Neither maxspeed nor maxspeed type info available for osmid 191228482
# Processing 10000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 22959737
# Neither maxspeed nor maxspeed type info available for osmid 22959737
# Neither maxspeed nor maxspeed type info available for osmid 48273148
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 714073114
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 562166783
# Neither maxspeed nor maxspeed type info available for osmid 23006207
# Neither maxspeed nor maxspeed type info available for osmid 4978512
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 22959737
# Neither maxspeed nor maxspeed type info available for osmid 22959737
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 152354692
# Neither maxspeed nor maxspeed type info available for osmid 23044858
# Neither maxspeed nor maxspeed type info available for osmid 23044858
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 126512818
# Neither maxspeed nor maxspeed type info available for osmid 23045995
# Neither maxspeed nor maxspeed type info available for osmid 25374267
# Neither maxspeed nor maxspeed type info available for osmid 23045995
# Neither maxspeed nor maxspeed type info available for osmid 23861004
# Neither maxspeed nor maxspeed type info available for osmid 152495033
# Neither maxspeed nor maxspeed type info available for osmid 320938558
# Neither maxspeed nor maxspeed type info available for osmid 241770501
# Neither maxspeed nor maxspeed type info available for osmid 52513361
# Neither maxspeed nor maxspeed type info available for osmid 130775103
# Neither maxspeed nor maxspeed type info available for osmid 659122809
# Neither maxspeed nor maxspeed type info available for osmid 33076218
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 27404071
# Neither maxspeed nor maxspeed type info available for osmid 232132513
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24656903
# Neither maxspeed nor maxspeed type info available for osmid 24204896
# Neither maxspeed nor maxspeed type info available for osmid 24204896
# Neither maxspeed nor maxspeed type info available for osmid 24204896
# Neither maxspeed nor maxspeed type info available for osmid 24205118
# Neither maxspeed nor maxspeed type info available for osmid 245077985
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 148626871
# Neither maxspeed nor maxspeed type info available for osmid 454285423
# Neither maxspeed nor maxspeed type info available for osmid 4610351
# Neither maxspeed nor maxspeed type info available for osmid 4978512
# Neither maxspeed nor maxspeed type info available for osmid 4978512
# Neither maxspeed nor maxspeed type info available for osmid 24036305
# Neither maxspeed nor maxspeed type info available for osmid 23382155
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 592333908
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 24036553
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 24036553
# Neither maxspeed nor maxspeed type info available for osmid 24036305
# Neither maxspeed nor maxspeed type info available for osmid 23382150
# Neither maxspeed nor maxspeed type info available for osmid 24036305
# Neither maxspeed nor maxspeed type info available for osmid 23382155
# Neither maxspeed nor maxspeed type info available for osmid 23389632
# Neither maxspeed nor maxspeed type info available for osmid 23389632
# Neither maxspeed nor maxspeed type info available for osmid 23389943
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 23409834
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 23409831
# Neither maxspeed nor maxspeed type info available for osmid 23409834
# Neither maxspeed nor maxspeed type info available for osmid 23409831
# Neither maxspeed nor maxspeed type info available for osmid 23410053
# Neither maxspeed nor maxspeed type info available for osmid 23410059
# Neither maxspeed nor maxspeed type info available for osmid 23410053
# Neither maxspeed nor maxspeed type info available for osmid 23410057
# Neither maxspeed nor maxspeed type info available for osmid 23410053
# Neither maxspeed nor maxspeed type info available for osmid 37143426
# Neither maxspeed nor maxspeed type info available for osmid 135708851
# Neither maxspeed nor maxspeed type info available for osmid 23410064
# Neither maxspeed nor maxspeed type info available for osmid 305137118
# Neither maxspeed nor maxspeed type info available for osmid 23411689
# Neither maxspeed nor maxspeed type info available for osmid 23411689
# Neither maxspeed nor maxspeed type info available for osmid 23411689
# Neither maxspeed nor maxspeed type info available for osmid 305137118
# Neither maxspeed nor maxspeed type info available for osmid 23411691
# Neither maxspeed nor maxspeed type info available for osmid 23411724
# Neither maxspeed nor maxspeed type info available for osmid 23411724
# Neither maxspeed nor maxspeed type info available for osmid 612040247
# Neither maxspeed nor maxspeed type info available for osmid 24667965
# Neither maxspeed nor maxspeed type info available for osmid 23436561
# Neither maxspeed nor maxspeed type info available for osmid 37291757
# Neither maxspeed nor maxspeed type info available for osmid 23436561
# Neither maxspeed nor maxspeed type info available for osmid 23436566
# Neither maxspeed nor maxspeed type info available for osmid 23436561
# Neither maxspeed nor maxspeed type info available for osmid 23436566
# Neither maxspeed nor maxspeed type info available for osmid 23436566
# Neither maxspeed nor maxspeed type info available for osmid 23451480
# Neither maxspeed nor maxspeed type info available for osmid 239336056
# Neither maxspeed nor maxspeed type info available for osmid 24432533
# Neither maxspeed nor maxspeed type info available for osmid 26236456
# Neither maxspeed nor maxspeed type info available for osmid 23536747
# Neither maxspeed nor maxspeed type info available for osmid 137071143
# Neither maxspeed nor maxspeed type info available for osmid 47266662
# Neither maxspeed nor maxspeed type info available for osmid 185897613
# Neither maxspeed nor maxspeed type info available for osmid 52513361
# Neither maxspeed nor maxspeed type info available for osmid 52513361
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 23597085
# Neither maxspeed nor maxspeed type info available for osmid 46148249
# Processing 11000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 24242835
# Neither maxspeed nor maxspeed type info available for osmid 8004043
# Neither maxspeed nor maxspeed type info available for osmid 4639037
# Neither maxspeed nor maxspeed type info available for osmid 31969137
# Neither maxspeed nor maxspeed type info available for osmid 4611890
# Neither maxspeed nor maxspeed type info available for osmid 27819621
# Neither maxspeed nor maxspeed type info available for osmid 23806793
# Neither maxspeed nor maxspeed type info available for osmid 486932694
# Neither maxspeed nor maxspeed type info available for osmid 23937611
# Neither maxspeed nor maxspeed type info available for osmid 23937615
# Neither maxspeed nor maxspeed type info available for osmid 28133482
# Neither maxspeed nor maxspeed type info available for osmid 23964735
# Neither maxspeed nor maxspeed type info available for osmid 23964735
# Neither maxspeed nor maxspeed type info available for osmid 23964737
# Neither maxspeed nor maxspeed type info available for osmid 23983948
# Neither maxspeed nor maxspeed type info available for osmid 23984630
# Neither maxspeed nor maxspeed type info available for osmid 42134108
# Neither maxspeed nor maxspeed type info available for osmid 152354619
# Neither maxspeed nor maxspeed type info available for osmid 8023538
# Neither maxspeed nor maxspeed type info available for osmid 8023538
# Neither maxspeed nor maxspeed type info available for osmid 24036553
# Neither maxspeed nor maxspeed type info available for osmid 24036553
# Neither maxspeed nor maxspeed type info available for osmid 24036564
# Neither maxspeed nor maxspeed type info available for osmid 592333909
# Neither maxspeed nor maxspeed type info available for osmid 27717049
# Neither maxspeed nor maxspeed type info available for osmid 24969046
# Neither maxspeed nor maxspeed type info available for osmid 24969049
# Neither maxspeed nor maxspeed type info available for osmid 26938218
# Neither maxspeed nor maxspeed type info available for osmid 22875395
# Neither maxspeed nor maxspeed type info available for osmid 22875395
# Neither maxspeed nor maxspeed type info available for osmid 22875255
# Neither maxspeed nor maxspeed type info available for osmid 24069491
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 155629835
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 24159569
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 24159569
# Neither maxspeed nor maxspeed type info available for osmid 195441539
# Neither maxspeed nor maxspeed type info available for osmid 195441538
# Neither maxspeed nor maxspeed type info available for osmid 195441536
# Found max speed in original graph
# ...
# Neither maxspeed nor maxspeed type info available for osmid 9031117
# Neither maxspeed nor maxspeed type info available for osmid 9031306
# Neither maxspeed nor maxspeed type info available for osmid 9031306
# Processing 44000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 45249568
# Neither maxspeed nor maxspeed type info available for osmid 9031633
# Neither maxspeed nor maxspeed type info available for osmid 105679491
# Neither maxspeed nor maxspeed type info available for osmid 81641192
# Neither maxspeed nor maxspeed type info available for osmid 81641192
# Neither maxspeed nor maxspeed type info available for osmid 878873781
# Neither maxspeed nor maxspeed type info available for osmid 172553155
# Neither maxspeed nor maxspeed type info available for osmid 604036523
# Neither maxspeed nor maxspeed type info available for osmid 604036523
# Neither maxspeed nor maxspeed type info available for osmid 709307060
# Neither maxspeed nor maxspeed type info available for osmid 272876719
# Neither maxspeed nor maxspeed type info available for osmid 52513273
# Neither maxspeed nor maxspeed type info available for osmid 52513273
# Neither maxspeed nor maxspeed type info available for osmid 52524384
# Neither maxspeed nor maxspeed type info available for osmid 5077357
# Neither maxspeed nor maxspeed type info available for osmid 52524384
# Neither maxspeed nor maxspeed type info available for osmid 52663773
# Neither maxspeed nor maxspeed type info available for osmid 52663773
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 714073114
# Neither maxspeed nor maxspeed type info available for osmid 29560616
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 142575701
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 26505940
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 4385195
# Neither maxspeed nor maxspeed type info available for osmid 4385195
# Neither maxspeed nor maxspeed type info available for osmid 64455490
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 108142293
# Neither maxspeed nor maxspeed type info available for osmid 107377988
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 4859820
# Neither maxspeed nor maxspeed type info available for osmid 27933744
# Neither maxspeed nor maxspeed type info available for osmid 729397316
# Neither maxspeed nor maxspeed type info available for osmid 671122316
# Neither maxspeed nor maxspeed type info available for osmid 734104656
# Neither maxspeed nor maxspeed type info available for osmid 289674738
# Neither maxspeed nor maxspeed type info available for osmid 741661400
# Neither maxspeed nor maxspeed type info available for osmid 27933165
# Neither maxspeed nor maxspeed type info available for osmid 55502709
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 747242964
# Neither maxspeed nor maxspeed type info available for osmid 749494726
# Neither maxspeed nor maxspeed type info available for osmid 749494726
# Neither maxspeed nor maxspeed type info available for osmid 27154460
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 868393437
# Neither maxspeed nor maxspeed type info available for osmid 868393437
# Neither maxspeed nor maxspeed type info available for osmid 55502709
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 10953524
# Neither maxspeed nor maxspeed type info available for osmid 57386690
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 704607593
# Neither maxspeed nor maxspeed type info available for osmid 58755943
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 4611782
# Neither maxspeed nor maxspeed type info available for osmid 770727438
# Neither maxspeed nor maxspeed type info available for osmid 770750182
# Neither maxspeed nor maxspeed type info available for osmid 152466415
# Neither maxspeed nor maxspeed type info available for osmid 58364018
# Neither maxspeed nor maxspeed type info available for osmid 59532088
# Neither maxspeed nor maxspeed type info available for osmid 59532086
# Neither maxspeed nor maxspeed type info available for osmid 58364015
# Neither maxspeed nor maxspeed type info available for osmid 59532086
# Neither maxspeed nor maxspeed type info available for osmid 59532086
# Neither maxspeed nor maxspeed type info available for osmid 59532087
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 9485797
# Neither maxspeed nor maxspeed type info available for osmid 9485797
# Neither maxspeed nor maxspeed type info available for osmid 782808776
# Neither maxspeed nor maxspeed type info available for osmid 782808776
# Neither maxspeed nor maxspeed type info available for osmid 780484402
# Neither maxspeed nor maxspeed type info available for osmid 257072321
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 195441539
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 195441538
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 195441538
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 31521784
# Neither maxspeed nor maxspeed type info available for osmid 151465254
# Neither maxspeed nor maxspeed type info available for osmid 26505940
# Neither maxspeed nor maxspeed type info available for osmid 59532086
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 793150994
# Neither maxspeed nor maxspeed type info available for osmid 59206064
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Neither maxspeed nor maxspeed type info available for osmid 23722412
# Neither maxspeed nor maxspeed type info available for osmid 4556354
# Neither maxspeed nor maxspeed type info available for osmid 9620794
# Neither maxspeed nor maxspeed type info available for osmid 9620794
# Neither maxspeed nor maxspeed type info available for osmid 268341946
# Neither maxspeed nor maxspeed type info available for osmid 857503740
# Neither maxspeed nor maxspeed type info available for osmid 857503740
# Neither maxspeed nor maxspeed type info available for osmid 331318343
# Neither maxspeed nor maxspeed type info available for osmid 331318343
# Processing 45000 of 46828 edges
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 31759808
# Neither maxspeed nor maxspeed type info available for osmid 532198758
# Neither maxspeed nor maxspeed type info available for osmid 532198758
# Neither maxspeed nor maxspeed type info available for osmid 532198758
# Neither maxspeed nor maxspeed type info available for osmid 254493283
# Neither maxspeed nor maxspeed type info available for osmid 9659868
# Neither maxspeed nor maxspeed type info available for osmid 60728013
# Neither maxspeed nor maxspeed type info available for osmid 60728013
# Found max speed in original graph
# Found max speed in original graph
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 60827398
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 60827398
# Neither maxspeed nor maxspeed type info available for osmid 694526969
# Neither maxspeed nor maxspeed type info available for osmid 694526969
# Neither maxspeed nor maxspeed type info available for osmid 694526969
# Neither maxspeed nor maxspeed type info available for osmid 694526969
# Neither maxspeed nor maxspeed type info available for osmid 60917396
# Neither maxspeed nor maxspeed type info available for osmid 694526969
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 29560616
# Neither maxspeed nor maxspeed type info available for osmid 746642315
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 847039379
# Neither maxspeed nor maxspeed type info available for osmid 822194556
# Neither maxspeed nor maxspeed type info available for osmid 312176585
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 58364015
# Neither maxspeed nor maxspeed type info available for osmid 746642315
# Neither maxspeed nor maxspeed type info available for osmid 140648433
# Neither maxspeed nor maxspeed type info available for osmid 826078426
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 256922648
# Neither maxspeed nor maxspeed type info available for osmid 62211376
# Neither maxspeed nor maxspeed type info available for osmid 832378190
# Neither maxspeed nor maxspeed type info available for osmid 29880839
# Neither maxspeed nor maxspeed type info available for osmid 14369553
# Neither maxspeed nor maxspeed type info available for osmid 822085421
# Neither maxspeed nor maxspeed type info available for osmid 328790102
# Neither maxspeed nor maxspeed type info available for osmid 4484149
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 158580757
# Neither maxspeed nor maxspeed type info available for osmid 855294855
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 193822259
# Neither maxspeed nor maxspeed type info available for osmid 862863118
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 868550032
# Neither maxspeed nor maxspeed type info available for osmid 868550033
# Neither maxspeed nor maxspeed type info available for osmid 4837326
# Neither maxspeed nor maxspeed type info available for osmid 874079009
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 455745095
# Neither maxspeed nor maxspeed type info available for osmid 881903095
# Neither maxspeed nor maxspeed type info available for osmid 881903097
# Neither maxspeed nor maxspeed type info available for osmid 887881590
# Neither maxspeed nor maxspeed type info available for osmid 39473297
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 211738841
# Neither maxspeed nor maxspeed type info available for osmid 69212650
# Neither maxspeed nor maxspeed type info available for osmid 10058489
# Neither maxspeed nor maxspeed type info available for osmid 889245350
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 211738841
# Neither maxspeed nor maxspeed type info available for osmid 4566442
# Neither maxspeed nor maxspeed type info available for osmid 71403156
# Neither maxspeed nor maxspeed type info available for osmid 153260646
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 58413394
# Neither maxspeed nor maxspeed type info available for osmid 240870777
# Neither maxspeed nor maxspeed type info available for osmid 74365210
# Neither maxspeed nor maxspeed type info available for osmid 147475701
# Neither maxspeed nor maxspeed type info available for osmid 19728123
# Processing 46000 of 46828 edges
# Neither maxspeed nor maxspeed type info available for osmid 151465254
# Neither maxspeed nor maxspeed type info available for osmid 151465254
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 24204439
# Neither maxspeed nor maxspeed type info available for osmid 24204443
# Neither maxspeed nor maxspeed type info available for osmid 76246485
# Neither maxspeed nor maxspeed type info available for osmid 10565256
# Neither maxspeed nor maxspeed type info available for osmid 79650605
# Neither maxspeed nor maxspeed type info available for osmid 79650605
# Neither maxspeed nor maxspeed type info available for osmid 25308380
# Neither maxspeed nor maxspeed type info available for osmid 4684837
# Neither maxspeed nor maxspeed type info available for osmid 25271028
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 57356014
# Neither maxspeed nor maxspeed type info available for osmid 82121185
# Neither maxspeed nor maxspeed type info available for osmid 173220885
# Found max speed type in original graph: DE:urban
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 10774708
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 26335165
# Neither maxspeed nor maxspeed type info available for osmid 813689598
# Neither maxspeed nor maxspeed type info available for osmid 813689598
# Neither maxspeed nor maxspeed type info available for osmid 25368898
# Neither maxspeed nor maxspeed type info available for osmid 5116453
# Neither maxspeed nor maxspeed type info available for osmid 40817796
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Found max speed type in original graph: DE:urban
# Neither maxspeed nor maxspeed type info available for osmid 136073775
# Neither maxspeed nor maxspeed type info available for osmid 527161303
# Neither maxspeed nor maxspeed type info available for osmid 140649658
# Neither maxspeed nor maxspeed type info available for osmid 138604846
# Neither maxspeed nor maxspeed type info available for osmid 11009143
# Neither maxspeed nor maxspeed type info available for osmid 34104006
# Neither maxspeed nor maxspeed type info available for osmid 34104006
# Neither maxspeed nor maxspeed type info available for osmid 11009167
# Neither maxspeed nor maxspeed type info available for osmid 11009167
# Neither maxspeed nor maxspeed type info available for osmid 11009167
# Neither maxspeed nor maxspeed type info available for osmid 11027581
# Neither maxspeed nor maxspeed type info available for osmid 11027581
# Neither maxspeed nor maxspeed type info available for osmid 145486354
# Neither maxspeed nor maxspeed type info available for osmid 11027581
# Neither maxspeed nor maxspeed type info available for osmid 11025158
# Neither maxspeed nor maxspeed type info available for osmid 11025158
# Neither maxspeed nor maxspeed type info available for osmid 11025429
# Neither maxspeed nor maxspeed type info available for osmid 11027988
# Neither maxspeed nor maxspeed type info available for osmid 137071151
# Found max speed in original graph
# Found max speed in original graph
# Found max speed in original graph
# Neither maxspeed nor maxspeed type info available for osmid 733106599
# Found max speed in original graph

# %%
# Convert maxSpeeds to numeric (includes some string artifacts)
print(np.unique(maxSpeeds))
edges["maxSpeed"] = pd.to_numeric(maxSpeeds, errors='coerce')
print("Road Segments without max speed:",
      round((edges.maxSpeed.isna().sum()/len(edges))*100,2), "%")
print("Number of considered edge segments:", len(edges))
edges.head()
# Out:
# ['10' '100' '120' '120.0' '15' '20' '30' '40' '5' '50' '60' '7' '70' '80'
#  'nan' 'walk']
# Road Segments without max speed: 4.97 %
# Number of considered edge segments: 46828
#                 edge_id     edge_1      edge_2  maxSpeed
# 0    100027768-29690836  100027768    29690836      30.0
# 1    100032633-29796810  100032633    29796810      50.0
# 2   100032633-433557530  100032633   433557530      50.0
# 3  100069498-1370811846  100069498  1370811846      30.0
# 4   100069498-268224213  100069498   268224213      30.0

# %%
# Merge above df with Rv data and get actual Rv
Rv = Rv.merge(edges, on="edge_id")
Rv = Rv.dropna(subset=["maxSpeed"]) # Drop rows with NaN
Rv.loc[:,"Rv"] = (Rv["meanspeed"]/Rv["maxSpeed"])
Rv.loc[Rv.Rv > 1, "Rv"] = 1  # Avoid artifacts where Rv > 1 because of wrong road speed info

# %%
# Add road segment status for each time
conditions = [
    (Rv.Rv < .25),
    ((Rv.Rv > .25) & (Rv.Rv <= .50)),
    ((Rv.Rv > .50) & (Rv.Rv <= .75)),
    (Rv.Rv > .75)
]

values = ["Heavy Congestion", "Mild Congestion", "Smooth", "Very Smooth"]
Rv['status'] = np.select(conditions, values)

# %%
Rv_status = Rv.merge((Rv[["edge_id", "time_id"]]
                      .groupby("edge_id")
                      .agg("count")), on="edge_id").rename(columns={"time_id_y": "T", "time_id_x": "time_id"})
Rv_status.head()
# Out:
#               edge_id  time_id   n  speed  meanspeed     edge_1    edge_2  \
# 0  100027768-29690836        7  25  231.0   9.240000  100027768  29690836
# 1  100027768-29690836        8  26  257.0   9.884615  100027768  29690836
# 2  100027768-29690836        9  26  156.0   6.000000  100027768  29690836
# 3  100027768-29690836       10  19  376.0  19.789474  100027768  29690836
# 4  100027768-29690836       29  33  392.0  11.878788  100027768  29690836
#
#    maxSpeed        Rv            status  T
# 0      30.0  0.308000   Mild Congestion  6
# 1      30.0  0.329487   Mild Congestion  6
# 2      30.0  0.200000  Heavy Congestion  6
# 3      30.0  0.659649            Smooth  6
# 4      30.0  0.395960   Mild Congestion  6

# %%
print(np.quantile(Rv_status.drop_duplicates(subset="edge_id")["T"], np.arange(0,1,.1)))

T_med = 0 # np.median(Rv_status.drop_duplicates(subset="edge_id")["T"])
print("Median:", T_med)

print("Number of observations with less than",
      T_med,
      "observation periods within the rush hour window:", 
      len(Rv_status[Rv_status["T"] < T_med].edge_id.unique()))
print("In percent: ", len(Rv_status[Rv_status["T"] < T_med].edge_id.unique())/len(edges))
      
Rv_status = Rv_status[Rv_status["T"] >= T_med] # drop T < T_med
# Out:
# [ 1.  2.  4. 11. 22. 34. 39. 40. 40. 40.]
# Median: 0
# Number of observations with less than 0 observation periods within the rush hour window: 0
# In percent:  0.0

# %%
# Add R_NC
Rv_status = Rv_status.merge(
    (Rv_status[["edge_id", "status"]]
     .groupby('edge_id')
     .status
     .apply(lambda x: ((x == 'Smooth') | (x == "Very Smooth")).mean())),
    on = "edge_id"
).rename(columns={'status_x':'status', 'status_y':'R_NC'})
Rv_status.head()
# Out:
#               edge_id  time_id   n  speed  meanspeed     edge_1    edge_2  \
# 0  100027768-29690836        7  25  231.0   9.240000  100027768  29690836
# 1  100027768-29690836        8  26  257.0   9.884615  100027768  29690836
# 2  100027768-29690836        9  26  156.0   6.000000  100027768  29690836
# 3  100027768-29690836       10  19  376.0  19.789474  100027768  29690836
# 4  100027768-29690836       29  33  392.0  11.878788  100027768  29690836
#
#    maxSpeed        Rv            status  T      R_NC
# 0      30.0  0.308000   Mild Congestion  6  0.166667
# 1      30.0  0.329487   Mild Congestion  6  0.166667
# 2      30.0  0.200000  Heavy Congestion  6  0.166667
# 3      30.0  0.659649            Smooth  6  0.166667
# 4      30.0  0.395960   Mild Congestion  6  0.166667

# %%
# Calculate R_i
RSI = Rv_status[["edge_id", "R_NC", "Rv", "maxSpeed"]].groupby(["edge_id", "R_NC", "maxSpeed"]).agg("mean")
RSI = RSI.reset_index(level=['R_NC', "maxSpeed"])
RSI.loc[:,"RSI"] = RSI.R_NC*RSI.Rv
RSI = RSI.sort_values("RSI")
RSI = RSI.reset_index(level="edge_id")
RSI[["edge_1", "edge_2"]] = RSI.edge_id.str.split("-", expand=True)
RSI["edge_1"] = RSI.edge_1.astype(int)
RSI["edge_2"] = RSI.edge_2.astype(int)
RSI = RSI.set_index("edge_id")
print(RSI.head())
print("We have the RSI for", len(RSI), "segments.")
print("In percent, this is", len(RSI)/len(edges),".")
# Out:
#                       R_NC  maxSpeed        Rv  RSI      edge_1     edge_2
# edge_id
# 999309349-999309353    0.0      30.0  0.282238  0.0   999309349  999309353
# 28378389-28378390      0.0      30.0  0.178342  0.0    28378389   28378390
# 28378390-28385627      0.0      30.0  0.140404  0.0    28378390   28385627
# 1656195152-260985798   0.0      50.0  0.324747  0.0  1656195152  260985798
# 28378395-28394275      0.0      30.0  0.303509  0.0    28378395   28394275
# We have the RSI for 44500 segments.
# In percent, this is 0.9502861535833262 .

# %%
# Print out the "top 10" congested road segments
x = []
for i in range(10):
    e1, e2 = RSI.index[i].split("-")
    e1, e2 = int(e1), int(e2)
    x.append(G[e1][e2])
    print(G[e1][e2])
# Out:
# {0: {'osmid': 37633352, 'lanes': '2', 'name': 'Scharnweberstraße', 'highway': 'tertiary', 'maxspeed': '50', 'oneway': False, 'length': 177.692, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeee11b7e20>, 'grade': 0.006, 'grade_abs': 0.006}}
# {0: {'osmid': 431571658, 'oneway': True, 'lanes': '3', 'name': 'Fritz-Erler-Allee', 'highway': 'tertiary', 'maxspeed': '50', 'length': 71.17699999999999, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeee5794d30>, 'grade': 0.0, 'grade_abs': 0.0}}
# {0: {'osmid': 15815831, 'name': 'Schwechtenstraße', 'highway': 'unclassified', 'maxspeed': '50', 'oneway': False, 'length': 441.963, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeef2dc8a90>, 'grade': 0.0, 'grade_abs': 0.0}}
# {0: {'osmid': 150257670, 'lanes': '3', 'ref': 'B 96', 'name': 'Oranienburger Chaussee', 'highway': 'primary', 'maxspeed': '50', 'oneway': False, 'length': 41.075, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeeea7c7640>, 'grade': -0.097, 'grade_abs': 0.097}}
# {0: {'osmid': [30718922, 462582767, 468161713, 30718931, 328440055], 'lanes': ['5', '4'], 'name': 'Seegefelder Straße', 'highway': 'tertiary', 'maxspeed': ['50', '30'], 'oneway': False, 'length': 292.02299999999997, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeee7e4f8b0>, 'grade': 0.003, 'grade_abs': 0.003}}
# {0: {'osmid': 307568352, 'oneway': True, 'lanes': '1', 'name': 'Zehlendorfer Damm', 'highway': 'tertiary_link', 'maxspeed': '50', 'length': 91.394, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeef2a32b50>, 'grade': 0.011, 'grade_abs': 0.011}}
# {0: {'osmid': 47975115, 'oneway': True, 'name': 'Seeburger Straße', 'highway': 'tertiary', 'maxspeed': '50', 'length': 53.714, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeee866fee0>, 'grade': 0.019, 'grade_abs': 0.019}}
# {0: {'osmid': 529791047, 'oneway': True, 'lanes': '3', 'name': 'Bundesallee', 'highway': 'secondary', 'maxspeed': '50', 'length': 48.4, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeee7e30a90>, 'grade': 0.0, 'grade_abs': 0.0}}
# {0: {'osmid': 24912365, 'oneway': True, 'lanes': '3', 'name': 'Hardenbergstraße', 'highway': 'secondary', 'maxspeed': '50', 'length': 18.308, 'grade': -0.437, 'grade_abs': 0.437}}
# {0: {'osmid': 813606312, 'name': 'Saalestraße', 'highway': 'residential', 'maxspeed': '50', 'oneway': False, 'length': 93.32200000000002, 'geometry': <shapely.geometry.linestring.LineString object at 0x2aeeeade7f70>, 'grade': 0.043, 'grade_abs': 0.043}}

# %%
# And we save it
RSI.to_csv("data/RSI-2020-sample-NOT-FILTERED.csv")

# %% [markdown]
# # Accident Prediction

# %%
# First: Train model
edges_accidents = pd.read_csv("data/edges_buffered_all_accidents.csv")
edges_accidents = edges_accidents[edges_accidents.RSI <= 0.5]

# Read RV data with n data for edge ids and time ids
Rv = pd.read_csv("data/Rv.csv", names = ['edge_id', 'time_id', 'n', 'speed', 'meanspeed'], skiprows=4)

# Take the sum over all times to get total n per year on edge
Rv = Rv["n"].groupby(Rv["edge_id"]).sum().reset_index()
Rv.rename(columns={"n":"flow_n"}, inplace=True)

# Merge with dataframe
edges_accidents = edges_accidents.merge(Rv, on="edge_id")

# Create logged variables
edges_accidents["log_flow_n"] = np.log(edges_accidents["flow_n"])
edges_accidents["log_flow_n_2"] =  np.power(edges_accidents["log_flow_n"], 2)

upper_thresh = 20
predictors = ["log_flow_n", "maxSpeed"]
target = "n_accidents"

# Get data
all_data = edges_accidents[edges_accidents.n_accidents <= upper_thresh]
all_data = all_data.sample(frac=1) # shuffle data randomly

# Get the model
zip_results = ZeroInflatedPoisson(endog = all_data[target], 
                                           exog = add_constant(all_data[predictors]),
                                           exog_infl = add_constant(all_data[predictors]), 
                                           inflation = 'logit').fit(maxiter=100)
# Out:
# /home/nikoch/.conda/envs/ma2/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /home/nikoch/.conda/envs/ma2/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.878981
#          Iterations: 34
#          Function evaluations: 39
#          Gradient evaluations: 39

# %%
RSI = pd.read_csv("data/RSI-2020-sample-NOT-FILTERED.csv", index_col=0)

# %%
# Retrieve nodes and edges as geodataframe
G = ox.io.load_graphml("data/graphs/berlin-2851.graphml")
H = ox.io.load_graphml("data/graphs/Berlin-raw.graphml")
nodes, edges = ox.graph_to_gdfs(G)

# MERGE TOGETHER THE G GDF WITH THE MORE INFORMATIVE H GDF AND ADD LANE INFO TO G.
H_edges = ox.graph_to_gdfs(H)[1][['osmid', 'maxspeed', 'surface', 'oneway', 'length',
       'lanes', 'maxspeed:type', 'ref', 'bridge', 'junction', 'width',
       'access', 'tunnel', 'service', 'area', 'est_width', 'geometry']]

edges = edges.join(H_edges, rsuffix="_y")

keepcols = ['osmid', 'name', 'highway', 'maxspeed', 'oneway', 'length', 'geometry',
       'grade', 'grade_abs', 'lanes', 'surface', 'maxspeed:type']
edges = edges[keepcols]

# %%
edges_buffered_all = gpd.GeoDataFrame(edges, geometry="geometry").set_crs(4326).to_crs(25833).reset_index()
edges_buffered_all['u'] = edges_buffered_all['u'].astype(str)
edges_buffered_all['v'] = edges_buffered_all['v'].astype(str)
edges_buffered_all["edge_id"] = edges_buffered_all[['u', 'v']].agg('-'.join, axis=1)
edges_buffered_all = edges_buffered_all.merge(RSI, on="edge_id")
edges_buffered_all = edges_buffered_all.dropna(subset=["RSI"]) # Drop all edges without RSI value

# %%
# Read RV data with n data for edge ids and time ids
Rv = pd.read_csv("data/Rv-2020-sample.csv", names = ['edge_id', 'time_id', 'n', 'speed', 'meanspeed'], skiprows=4)

# Take the sum over all times to get total n per year on edge
Rv = Rv["n"].groupby(Rv["edge_id"]).sum().reset_index()
Rv.rename(columns={"n":"flow_n"}, inplace=True)

# Merge with dataframe
edges_buffered_all = edges_buffered_all.merge(Rv, on="edge_id")

# %%
(edges_buffered_all[["edge_id", "maxSpeed", "RSI", "flow_n"]].
 to_csv("data/sample-to-predict-accidents-NOT-FILTERED.csv", index=False))

# %%
# Read in new data and filter to only include part of the data where RSI in 2017 is smaller than .5 as well
new = pd.read_csv("data/sample-to-predict-accidents-NOT-FILTERED.csv")
print(len(new)) # 22407
new = new[new.edge_id.isin(all_data.edge_id)].drop_duplicates(subset="edge_id")
print(len(new)) # 7725
new["log_flow_n"] = np.log(new.flow_n)
# Out:
# 44735
# 8011

# %%
# Get the predictions
new_results = np.round(
    zip_results.predict(exog=add_constant(new[predictors]),
                        exog_infl=add_constant(new[predictors])),
    0)
# Out:
# /home/nikoch/.conda/envs/ma2/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
print("N accidents in 2017:", all_data[target].sum())
print("N accidents in 2020:", int(np.sum(new_results)))
print("Difference:", int(all_data[target].sum()-np.sum(new_results)))
# Out:
# N accidents in 2017: 3833
# N accidents in 2020: 3217
# Difference: 616
