# %%
# Imports, options
import os
import pandas as pd

from config import rpath
os.chdir(rpath)

# %%
indicators = pd.read_csv("data/indicators.csv")
indicators = indicators[indicators.uc_id==2851]

# %%
indicators.T
# Out:
#                                       6767
# country                            germany
# country_iso                            DEU
# core_city                           berlin
# uc_id                                 2851
# cc_avg_dir                        0.037444
# cc_avg_undir                       0.05236
# cc_wt_avg_dir                     0.000664
# cc_wt_avg_undir                   0.000799
# circuity                          1.038662
# elev_iqr                              12.0
# elev_mean                        44.708529
# elev_median                           44.0
# elev_range                            66.0
# elev_std                          8.239551
# grade_mean                         0.01803
# grade_median                         0.009
# intersect_count                      24908
# intersect_count_clean                21083
# intersect_count_clean_topo           21189
# k_avg                             3.007798
# length_mean                     142.339484
# ...
