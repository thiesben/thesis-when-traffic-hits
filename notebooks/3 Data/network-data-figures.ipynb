# %%
# Imports, parameters
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os
import rasterio
# from matplotlib.ticker import FormatStrFormatter
from rasterio.features import shapes

from config import rpath
os.chdir(rpath)

# %% [markdown]
# ## Data
#
# **Figure: Berlin administrative boundaries vs. Berlin as an urban centre**

# %%
# Loading Berlin administrative boundaries and Berlin UC
berlin_adm = gpd.read_file("data/geodata/berlin/bezirksgrenzen.shp")
berlin_uc = gpd.read_file("data/geodata/GHS/GHS_STAT_UCDB2015MT_GLOBE_R2019A_V1_2.gpkg")
berlin_uc = berlin_uc[berlin_uc.UC_NM_MN=="Berlin"]

# %%
# Plot it
fig, ax = plt.subplots(1,1)
berlin_uc.plot(ax=ax, color="lightskyblue")
berlin_adm.plot(alpha=1, edgecolor="black", facecolor="None", ax=ax)
ax.set_ylabel("Latitude")
ax.set_xlabel("Longitude")
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.show()

# %% [markdown]
# **Figure: Simplified and non-simplified network**:
# We retrieve the area around Berlin Alexanderplatz in raw format and simplify it, then plot them both to show the difference.

# %%
raw = ox.graph_from_bbox(52.525023, 52.518977, 13.418095, 13.407347, simplify=False, network_type="drive")
simplified = ox.simplification.simplify_graph(raw)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,20))
ox.plot_graph(raw, node_color='red',
              ax=axs[0], close=False, show=False)
ox.plot_graph(simplified, node_color='red',
              ax=axs[1], close=False, show=False)
axs = axs.flatten()
for ax in axs:
    ax.spines["top"].set_visible(True)
    ax.spines["bottom"].set_visible(True)
    ax.spines["right"].set_visible(True)
    ax.spines["left"].set_visible(True)
    # ax.set_facecolor('black')
plt.show()
