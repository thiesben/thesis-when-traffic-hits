# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from shapely.geometry import LineString

# %%
a = gpd.read_file("street-buffer-example-1.geojson").to_crs(3857)
b = gpd.read_file("street-buffer-example-2.geojson").to_crs(3857)

# %%
ax = b.plot(figsize=(10, 10), facecolor="lightblue", alpha=.4, edgecolor="blue")
a.plot(ax=ax, color="blue")
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
ax.get_yaxis().set_visible(False)
ax.axes.get_xaxis().set_visible(False)
plt.show()
