# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import networkx as nx
import numpy as np
import os 
from collections import Counter

from config import rpath
os.chdir(rpath)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

img1 = mpimg.imread('img/graph-undirected.png')
img2 = mpimg.imread('img/graph-directed.png')


ax[0].imshow(img1)
ax[1].imshow(img2)
for a in ax:
    a.axes.get_xaxis().set_visible(False)
    a.axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.subplots_adjust(wspace=0.2)
plt.savefig('img/graphs.png')
plt.show()

# %% [markdown]
# # Distribution of above graph

# %%
G = nx.Graph()
G.add_nodes_from([1,2, 3])
G.add_edges_from([(1, 2), (2, 3), (3,1)])

# %%
# From analysis-descriptive.ipynb
def round_next_order(no):
    for i in range(2, 10):
        if np.round(no,i) == 0:
            next
        else:
            return(np.round(no, i))

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence # undirected graph
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
total = sum([count for key, count in degreeCount.items()])
freq = [c/total for c in cnt]

fig, ax = plt.subplots(figsize=(7,5))
plt.bar(deg, freq, width=0.80, edgecolor="k")

plt.ylabel("Relative Frequency $P(k)$", fontsize=12)
plt.xlabel("Degree $\mathregular{k_i}$", fontsize=12)

ax.set_xticks([0,1,2,3])
ax.set_xticklabels([0,1,2,3])

plt.show()

# %% [markdown]
# # Planar and non-planar graphs

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))

img1 = mpimg.imread('img/graph-planar.png')
img2 = mpimg.imread('img/graph-halfplanar-red.png')
img3 = mpimg.imread('img/graph-nonplanar-red.png')

ax[0].imshow(img1)
ax[1].imshow(img2)
ax[2].imshow(img3)

for a in ax:
    a.axes.get_yaxis().set_visible(False)
    a.axes.get_xaxis().set_visible(False)
plt.tight_layout()
plt.subplots_adjust(wspace=0.2)
plt.savefig('img/planarity-graphs.png')
plt.show()

# %%
'osm_living-street.jpg'[:-4]
# Out:
# 'osm_living-street'

# %%
images = ['osm_living-street.jpg', 'osm_residential.jpg', 'osm_secondary.jpg',
          'osm_secondary-link.jpg', 'osm_tertiary.jpg', 'osm_unclassified.jpg']

for image in images:
    fig, ax = plt.subplots(1,1, figsize=(5,5))
    img = mpimg.imread('img/' + image)

    ax.imshow(img)

    ax.get_yaxis().set_visible(False)
    ax.axes.get_xaxis().set_visible(False)
    plt.tight_layout()
    plt.subplots_adjust(wspace=0.2)
    plt.savefig('img/' + image[:-4] + '.png')
    plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

img1 = mpimg.imread('img/RSI_segments.png')
img2 = mpimg.imread('img/RSI_segments_buffered_accidents.png')

# ax=ax.flatten()
ax[0].imshow(img1)
ax[1].imshow(img2)
for a in ax:
    a.axes.get_xaxis().set_visible(False)
    a.axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.subplots_adjust(wspace=0.1)
plt.savefig('img/RSI_segments_and_accidents.png', dpi=800)
plt.show()

# %%
images = ['osm_6way_intersection.jpg']

for image in images:
    fig, ax = plt.subplots(1,1, figsize=(8,8))
    img = mpimg.imread('img/' + image)

    ax.imshow(img)

    ax.get_yaxis().set_visible(False)
    ax.axes.get_xaxis().set_visible(False)
    plt.tight_layout()
    plt.subplots_adjust(wspace=0.2)
    plt.savefig('img/' + image[:-4] + '.png')
    plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

img1 = mpimg.imread('img/PLACEHOLDER_betweenness_centrality_discretized.png')
img2 = mpimg.imread('img/PLACEHOLDER_traffic_n_discretized.png')

# ax=ax.flatten()
ax[0].imshow(img1)
ax[1].imshow(img2)
for a in ax:
    a.axes.get_xaxis().set_visible(False)
    a.axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.subplots_adjust(wspace=0.1)
plt.savefig('img/PLACEHOLDER_betweenness_vs_traffic.png', dpi=800)
plt.show()
